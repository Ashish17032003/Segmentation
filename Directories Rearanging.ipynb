# %%
# !pip install nibabel
# Out:
# ...
#   Using cached nibabel-5.1.0-py3-none-any.whl (3.3 MB)
# ...

# %%
import os
import nibabel as nib
import glob

# %%
train_dataset_path = 'C:\\Users\\KIIT\\Documents\\ML\\Segmentation\\BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\'
target_folder = 'C:\\Users\\KIIT\\Documents\\ML\\Segmentation\\BraTS2020_TrainingData\\MICCAI_BraTS2020_TrainingData\\'

# %%
dir_list = os.listdir(train_dataset_path)
dir_list[0]
# Out:
# 'BraTS20_Training_001'

# %%
#No need to run this
f = []
for i in range(len(dir_list)):
    main_sub_path = os.path.join(train_dataset_path, dir_list[i])
    files = os.listdir(main_sub_path)
    for i in files:
        print(i)
    print('--------------------------------------')
# Out:
# BraTS20_Training_001_flair.nii
# BraTS20_Training_001_seg.nii
# BraTS20_Training_001_t1.nii
# BraTS20_Training_001_t1ce.nii
# BraTS20_Training_001_t2.nii
# --------------------------------------
# BraTS20_Training_002_flair.nii
# BraTS20_Training_002_seg.nii
# BraTS20_Training_002_t1.nii
# BraTS20_Training_002_t1ce.nii
# BraTS20_Training_002_t2.nii
# --------------------------------------
# BraTS20_Training_003_flair.nii
# BraTS20_Training_003_seg.nii
# BraTS20_Training_003_t1.nii
# BraTS20_Training_003_t1ce.nii
# BraTS20_Training_003_t2.nii
# --------------------------------------
# BraTS20_Training_004_flair.nii
# BraTS20_Training_004_seg.nii
# BraTS20_Training_004_t1.nii
# BraTS20_Training_004_t1ce.nii
# BraTS20_Training_004_t2.nii
# --------------------------------------
# BraTS20_Training_005_flair.nii
# BraTS20_Training_005_seg.nii
# BraTS20_Training_005_t1.nii
# BraTS20_Training_005_t1ce.nii
# BraTS20_Training_005_t2.nii
# --------------------------------------
# ...

# %%
for path, dir, files in os.walk(train_dataset_path):
    if files:
        for file in files:
            if os.path.isfile:
                if not os.path.isfile(target_folder + file):
                    os.rename(path + '\\' + file, target_folder + file)
